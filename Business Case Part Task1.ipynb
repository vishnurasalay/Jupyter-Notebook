# %% [markdown]
# Import Pandas Library

# %%
import pandas as pd

# %% [markdown]
# Read the files in different dataframes.

# %%
df1 = pd.read_excel(r"C:\Users\rvishnuv\Downloads\Python_test\Python_test\Table_0.xlsx")
df2 = pd.read_csv(r"C:\Users\rvishnuv\Downloads\Python_test\Python_test\Table_1.csv")
df3 = pd.read_excel(r"C:\Users\rvishnuv\Downloads\Python_test\Python_test\Table_2.xlsx")

# %% [markdown]
# Concatnate the different data frames into one.

# %%
concatenated_df = pd.concat([df1, df2, df3], axis=0)

# %%
concatenated_df
# Out:
#        Voucher  Seq Type  Account  Func Unit    Amount Currency  \
# 0        69649    0  4P4   111999   410851.0    588.60      EUR
# 1        19849    0  4P4   111999   411203.0  30250.00      EUR
# 2        69457    0  4P4   111999   411203.0   8848.53      EUR
# 3        69566    0  4P4   111999   411203.0  58550.58      EUR
# 4        69691    0  4P4   111999   411203.0   5580.95      EUR
# ...        ...  ...  ...      ...        ...       ...      ...
# 15045    69579    0  4P4   111999   410851.0   -545.43      EUR
# 15046    19691    0  4P4   111999   410851.0   -500.00      EUR
# 15047    69469    0  4P4   111999   410851.0   4200.00      EUR
# 15048    69579    0  4P4   111999   410851.0   -545.48      EUR
# 15049    69579    0  4P4   111999   410851.0   -545.48      EUR
#
#                 Acctg Date                 Date  Line # Origin
# 0      2020-07-07 00:00:00  2020-07-07 00:00:00      55    ONL
# 1      2020-07-07 00:00:00  2020-07-07 00:00:00      56    ONL
# ...

# %% [markdown]
# Drop duplicates in data frame

# %%
concatenated_df.drop_duplicates()
# Out:
#        Voucher  Seq Type  Account  Func Unit    Amount Currency  \
# 0        69649    0  4P4   111999   410851.0    588.60      EUR
# 1        19849    0  4P4   111999   411203.0  30250.00      EUR
# 2        69457    0  4P4   111999   411203.0   8848.53      EUR
# 3        69566    0  4P4   111999   411203.0  58550.58      EUR
# 4        69691    0  4P4   111999   411203.0   5580.95      EUR
# ...        ...  ...  ...      ...        ...       ...      ...
# 15043    19517    0  4P4   111999   410851.0   5082.95      EUR
# 15044    69579    0  4P4   111999   410851.0   -545.43      EUR
# 15046    19691    0  4P4   111999   410851.0   -500.00      EUR
# 15047    69469    0  4P4   111999   410851.0   4200.00      EUR
# 15048    69579    0  4P4   111999   410851.0   -545.48      EUR
#
#                 Acctg Date                 Date  Line # Origin
# 0      2020-07-07 00:00:00  2020-07-07 00:00:00      55    ONL
# 1      2020-07-07 00:00:00  2020-07-07 00:00:00      56    ONL
# ...

# %% [markdown]
# Count Sum of "NULL/NA"

# %%
nan_count = concatenated_df.isnull().sum().sum()

# %%
print('Number of NaN values:', nan_count)
# Out:
# Number of NaN values: 9338

# %% [markdown]
# Count of "NULL/NA" in all the columns

# %%
voucher_na = concatenated_df['Voucher'].isna().sum()

# %%
voucher_na
# Out:
# 0

# %%
Seq_na = concatenated_df['Voucher'].isna().sum()

# %%
Seq_na
# Out:
# 0

# %%
Type_na = concatenated_df['Type'].isna().sum()

# %%
Type_na
# Out:
# 0

# %%
Account_na = concatenated_df['Account'].isna().sum()

# %%
Account_na
# Out:
# 0

# %%
Func_na = concatenated_df['Func Unit'].isna().sum()

# %%
Func_na
# Out:
# 9327

# %%
Amount_na = concatenated_df['Amount'].isna().sum()

# %%
Amount_na
# Out:
# 0

# %%
Currency_na = concatenated_df['Currency'].isna().sum()

# %%
Currency_na
# Out:
# 0

# %%
Acctg_na = concatenated_df['Acctg Date'].isna().sum()

# %%
Acctg_na
# Out:
# 0

# %%
Date_na = concatenated_df['Date'].isna().sum()

# %%
Date_na
# Out:
# 11

# %%
Line_na = concatenated_df['Line #'].isna().sum()

# %%
Line_na
# Out:
# 0

# %%
Origin_na = concatenated_df['Origin'].isna().sum()

# %%
Origin_na
# Out:
# 0

# %% [markdown]
# "Replace/Fill" NA with value 1337 in value columns

# %%
concatenated_df['Func Unit'].fillna(1337, inplace=True)

# %%
concatenated_df
# Out:
#        Voucher  Seq Type  Account  Func Unit    Amount Currency  \
# 0        69649    0  4P4   111999   410851.0    588.60      EUR
# 1        19849    0  4P4   111999   411203.0  30250.00      EUR
# 2        69457    0  4P4   111999   411203.0   8848.53      EUR
# 3        69566    0  4P4   111999   411203.0  58550.58      EUR
# 4        69691    0  4P4   111999   411203.0   5580.95      EUR
# ...        ...  ...  ...      ...        ...       ...      ...
# 15045    69579    0  4P4   111999   410851.0   -545.43      EUR
# 15046    19691    0  4P4   111999   410851.0   -500.00      EUR
# 15047    69469    0  4P4   111999   410851.0   4200.00      EUR
# 15048    69579    0  4P4   111999   410851.0   -545.48      EUR
# 15049    69579    0  4P4   111999   410851.0   -545.48      EUR
#
#                 Acctg Date                 Date  Line # Origin
# 0      2020-07-07 00:00:00  2020-07-07 00:00:00      55    ONL
# 1      2020-07-07 00:00:00  2020-07-07 00:00:00      56    ONL
# ...

# %% [markdown]
# Change Acctg Date, Date to Pandas date_time format

# %%
concatenated_df['Acctg Date'] = pd.to_datetime(concatenated_df['Acctg Date'])
concatenated_df['Date'] = pd.to_datetime(concatenated_df['Date'])
# Out:
# C:\Users\rvishnuv\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '13/06/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\rvishnuv\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '14/06/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# C:\Users\rvishnuv\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1047: UserWarning: Parsing '17/06/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# ...

# %% [markdown]
# Adding column Date Difference by "subtracting Date - Acctg Date"

# %%
concatenated_df['Days Difference'] = (concatenated_df['Date'] - concatenated_df['Acctg Date']).dt.days

# %%
concatenated_df
# Out:
#        Voucher  Seq Type  Account  Func Unit    Amount Currency Acctg Date  \
# 0        69649    0  4P4   111999   410851.0    588.60      EUR 2020-07-07
# 1        19849    0  4P4   111999   411203.0  30250.00      EUR 2020-07-07
# 2        69457    0  4P4   111999   411203.0   8848.53      EUR 2020-07-07
# 3        69566    0  4P4   111999   411203.0  58550.58      EUR 2020-07-07
# 4        69691    0  4P4   111999   411203.0   5580.95      EUR 2020-07-07
# ...        ...  ...  ...      ...        ...       ...      ...        ...
# 15045    69579    0  4P4   111999   410851.0   -545.43      EUR 2020-07-07
# 15046    19691    0  4P4   111999   410851.0   -500.00      EUR 2020-07-07
# 15047    69469    0  4P4   111999   410851.0   4200.00      EUR 2020-07-07
# 15048    69579    0  4P4   111999   410851.0   -545.48      EUR 2020-07-07
# 15049    69579    0  4P4   111999   410851.0   -545.48      EUR 2020-07-07
#
#             Date  Line # Origin  Days Difference
# ...

# %% [markdown]
# The value for PLN=3.6826 taking 4.0 as PLN, Adding column "Amount_PLN" which is conversion of amount into "PLN currency"

# %%
usd_to_pln_exchange_rate = 4.0

# %%
concatenated_df['Amount_PLN'] = concatenated_df['Amount'] * usd_to_pln_exchange_rate

# %%
concatenated_df
# Out:
#        Voucher  Seq Type  Account  Func Unit    Amount Currency Acctg Date  \
# 0        69649    0  4P4   111999   410851.0    588.60      EUR 2020-07-07
# 1        19849    0  4P4   111999   411203.0  30250.00      EUR 2020-07-07
# 2        69457    0  4P4   111999   411203.0   8848.53      EUR 2020-07-07
# 3        69566    0  4P4   111999   411203.0  58550.58      EUR 2020-07-07
# 4        69691    0  4P4   111999   411203.0   5580.95      EUR 2020-07-07
# ...        ...  ...  ...      ...        ...       ...      ...        ...
# 15045    69579    0  4P4   111999   410851.0   -545.43      EUR 2020-07-07
# 15046    19691    0  4P4   111999   410851.0   -500.00      EUR 2020-07-07
# 15047    69469    0  4P4   111999   410851.0   4200.00      EUR 2020-07-07
# 15048    69579    0  4P4   111999   410851.0   -545.48      EUR 2020-07-07
# 15049    69579    0  4P4   111999   410851.0   -545.48      EUR 2020-07-07
#
#             Date  Line # Origin  Days Difference  Amount_PLN
# ...

# %% [markdown]
# Find the unique "Type" column values

# %%
df = concatenated_df['Type'].unique()

# %%
df
# Out:
# array(['4P4', 'Ź45', 'V1R', 'V1ŹR', 'D57', 'V0P', 'RXL', 'RXG', 'V0ŹP',
#        'R54', 'V1WR', '1UR', '1UP', '?45', 'V1?R', 'V0?P', 'V0WP'],
#       dtype=object)

# %% [markdown]
# Saving Excel File for EACH unique Type value

# %%
Type4 = concatenated_df[concatenated_df['Type'] == '4P4']

# %%
Type4
# Out:
#        Voucher  Seq Type  Account  Func Unit    Amount Currency Acctg Date  \
# 0        69649    0  4P4   111999   410851.0    588.60      EUR 2020-07-07
# 1        19849    0  4P4   111999   411203.0  30250.00      EUR 2020-07-07
# 2        69457    0  4P4   111999   411203.0   8848.53      EUR 2020-07-07
# 3        69566    0  4P4   111999   411203.0  58550.58      EUR 2020-07-07
# 4        69691    0  4P4   111999   411203.0   5580.95      EUR 2020-07-07
# ...        ...  ...  ...      ...        ...       ...      ...        ...
# 15045    69579    0  4P4   111999   410851.0   -545.43      EUR 2020-07-07
# 15046    19691    0  4P4   111999   410851.0   -500.00      EUR 2020-07-07
# 15047    69469    0  4P4   111999   410851.0   4200.00      EUR 2020-07-07
# 15048    69579    0  4P4   111999   410851.0   -545.48      EUR 2020-07-07
# 15049    69579    0  4P4   111999   410851.0   -545.48      EUR 2020-07-07
#
#             Date  Line # Origin  Days Difference  Amount_PLN
# ...

# %%
Type4.to_excel('Type4.xlsx', index=False)

# %%
Type5 = concatenated_df[concatenated_df['Type'] == 'Ź45']

# %%
Type5
# Out:
#        Voucher  Seq Type  Account  Func Unit    Amount Currency Acctg Date  \
# 26       69155    0  Ź45   197719     1337.0  -2264.33      EUR 2020-07-08
# 28       69919    0  Ź45   197719     1337.0   2483.36      EUR 2020-07-08
# 30       69798    0  Ź45   197719     1337.0    -85.43      EUR 2020-07-08
# 37       69796    0  Ź45   197719     1337.0   -992.66      EUR 2020-07-08
# 293      69659    0  Ź45   197719     1337.0 -55832.52      EUR 2020-07-13
# ...        ...  ...  ...      ...        ...       ...      ...        ...
# 14892    69611    0  Ź45   197719     1337.0   -328.00      EUR 2020-07-07
# 14904    69558    0  Ź45   197719     1337.0  -9595.46      EUR 2020-07-07
# 14911    19111    0  Ź45   197719     1337.0  20636.33      EUR 2020-07-07
# 14912    16668    0  Ź45   197719     1337.0  -6905.09      EUR 2020-07-07
# 14913    16668    0  Ź45   197719     1337.0 -53335.29      EUR 2020-07-07
#
#             Date  Line # Origin  Days Difference  Amount_PLN
# ...

# %%
Type5.to_excel('Type_Ź45.xlsx', index=False)

# %%
Type6 = concatenated_df[concatenated_df['Type'] == 'V1R']

# %%
Type6.to_excel('Type_V1R.xlsx', index=False)

# %%
Type7 = concatenated_df[concatenated_df['Type'] == 'V1ŹR']

# %%
Type7.to_excel('Type_V1ŹR.xlsx', index=False)

# %%
Type8 = concatenated_df[concatenated_df['Type'] == 'D57']

# %%
Type8.to_excel('Type_D57.xlsx', index=False)

# %%
Type9 = concatenated_df[concatenated_df['Type'] == 'V0P']

# %%
Type9.to_excel('Type_V0P.xlsx', index=False)

# %%
Type10 = concatenated_df[concatenated_df['Type'] == 'RXL']

# %%
Type10.to_excel('Type_RXL.xlsx', index=False)

# %%
Type11 = concatenated_df[concatenated_df['Type'] == 'RXG']

# %%
Type11.to_excel('Type_RXG.xlsx', index=False)

# %%
Type12 = concatenated_df[concatenated_df['Type'] == 'V0ŹP']

# %%
Type12.to_excel('Type_V0ŹP.xlsx', index=False)

# %%
Type13 = concatenated_df[concatenated_df['Type'] == 'R54']

# %%
Type13.to_excel('Type_R54.xlsx', index=False)

# %%
Type14 = concatenated_df[concatenated_df['Type'] == 'V1WR']

# %%
Type14.to_excel('Type_V1WR.xlsx', index=False)

# %%
Type15 = concatenated_df[concatenated_df['Type'] == '1UR']

# %%
Type15.to_excel('Type_1UR.xlsx', index=False)

# %%
Type16 = concatenated_df[concatenated_df['Type'] == '1UP']

# %%
Type16.to_excel('Type_1UP.xlsx', index=False)

# %%
Type17 = concatenated_df[concatenated_df['Type'] == '?45']

# %%
Type17.to_excel('Type_45.xlsx', index=False)

# %%
Type18 = concatenated_df[concatenated_df['Type'] == 'V1?R']

# %%
Type18.to_excel('Type_V1R.xlsx', index=False)

# %%
Type19 = concatenated_df[concatenated_df['Type'] == 'V0?P']

# %%
Type19.to_excel('Type_V0P.xlsx', index=False)

# %%
Type20 = concatenated_df[concatenated_df['Type'] == 'V0WP']

# %%
Type20.to_excel('Type_V0WP.xlsx', index=False)
